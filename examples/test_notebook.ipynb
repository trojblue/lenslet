# %%
import unibox as ub

imgs = ub.ls("s3://bucket-public-access-uw2/labelling/aes-labelling-ai-7.2k/")
# Out:
# 2025-11-27 01:58:46 [INFO] ls: Listing contents of s3://bucket-public-access-uw2/labelling/aes-labelling-ai-7.2k/
# Traversing S3: 0page [00:00, ?page/s]

# %%
import lenslet

# Example: Launch with a list of local image paths
datasets = {
    "my_photos": imgs
}

# Launch in non-blocking mode (returns immediately)
lenslet.launch(datasets, blocking=False, port=17271)
# Out:
# ┌─────────────────────────────────────────────────┐
# │                   🔍 Lenslet                    │
# │         Lightweight Image Gallery Server        │
# ├─────────────────────────────────────────────────┤
# │  Datasets:  my_photos                           │
# │  Images:    7189                                │
# │  Server:    http://127.0.0.1:17271                    │
# │  Mode:      Subprocess (non-blocking)           │
# │  PID:       3548873                             │
# └─────────────────────────────────────────────────┘
#
# Gallery running at: http://127.0.0.1:17271
